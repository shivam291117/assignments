# %% [markdown]
# Q1. What are the three measures of central tendency?
#
# Mean, median, mode

# %% [markdown]
# Q2. What is the difference between the mean, median, and mode? How are they used to measure the
# central tendency of a dataset?

# %% [markdown]
# 1. mean is the average value
# 2. median is the middle value
# 3. mode is the value that appears maximum numbe of times in the data set

# %% [markdown]
# Q3. Measure the three measures of central tendency for the given height data:
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %% [markdown]
# 1. Mean: 176.71
# 2. Median: 177
# 3. Mode : 177,178 (bimodal)

# %% [markdown]
# Q4. Find the standard deviation for the given data:
#
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]
#
# Ans. 1.71

# %% [markdown]
# Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe
# the spread of a dataset?
#
# Provide an example.
#
# Ans.
#
#
# Measures of dispersion such as range, variance, and standard deviation are used to quantify the extent to which data points in a dataset vary or spread out from the central tendency (mean or median). They provide important insights into the variability and distribution of the data points.
#
# 1. Range
# Definition: The range is the difference between the maximum and minimum values in a dataset.
#
# Range
# =
# Maximum value
# −
# Minimum value
# Range=Maximum value−Minimum value
#
# Example: Consider the heights of students in a class: [160, 165, 170, 175, 180].
#
# Maximum height = 180
# Minimum height = 160
# Range
# =
# 180
# −
# 160
# =
# 20
# Range=180−160=20
#
# The range is 20 units, indicating the spread of heights from the shortest to the tallest student.
#
# 2. Variance
# Definition: The variance measures how much each data point differs from the mean of the dataset. It is the average of the squared differences from the mean.
#
# Variance
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
# −
# 1
# Variance=
# n−1
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
#
# where
# 𝑥
# 𝑖
# x
# i
# ​
#   are the data points,
# 𝑥
# ˉ
# x
# ˉ
#   is the mean, and
# 𝑛
# n is the number of data points.
#
# Example: Consider the following dataset of test scores: [70, 75, 80, 85, 90].
#
# Calculate the mean
# 𝑥
# ˉ
# x
# ˉ
#  :
# 𝑥
# ˉ
# =
# 70
# +
# 75
# +
# 80
# +
# 85
# +
# 90
# 5
# =
# 80
# x
# ˉ
#  =
# 5
# 70+75+80+85+90
# ​
#  =80
#
# Calculate the squared differences from the mean:
# (
# 70
# −
# 80
# )
# 2
# =
# 100
# (70−80)
# 2
#  =100
# (
# 75
# −
# 80
# )
# 2
# =
# 25
# (75−80)
# 2
#  =25
# (
# 80
# −
# 80
# )
# 2
# =
# 0
# (80−80)
# 2
#  =0
# (
# 85
# −
# 80
# )
# 2
# =
# 25
# (85−80)
# 2
#  =25
# (
# 90
# −
# 80
# )
# 2
# =
# 100
# (90−80)
# 2
#  =100
#
# Sum the squared differences:
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# =
# 250
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#  =250
#
# Calculate the variance:
# Variance
# =
# 250
# 5
# −
# 1
# =
# 250
# 4
# =
# 62.5
# Variance=
# 5−1
# 250
# ​
#  =
# 4
# 250
# ​
#  =62.5
#
# The variance is 62.5, indicating the average squared deviation from the mean test score.
#
# 3. Standard Deviation
# Definition: The standard deviation is the square root of the variance. It measures the average amount of variation or dispersion of data points from the mean.
#
# Standard Deviation
# =
# Variance
# Standard Deviation=
# Variance
# ​
#
#
# Example: Using the previous example, the variance was 62.5.
#
# Standard Deviation
# =
# 62.5
# ≈
# 7.91
# Standard Deviation=
# 62.5
# ​
#  ≈7.91
#
# The standard deviation is approximately 7.91, indicating the average deviation of test scores from the mean score of 80.
#
# Usage

# %% [markdown]
# Q6. What is a Venn Diagram ?
#
# Ans.
#
# A Venn diagram uses overlapping circles or other shapes to illustrate the logical relationships between two or more sets of items. Often, they serve to graphically organize things, highlighting how the items are similar and different.

# %% [markdown]
# Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10).
#
# Find:
#
# (i) A intersection B - (2,6)
#
# (ii) A ⋃ B - (0,2,3,4,5,6,7,8,10)

# %% [markdown]
# Q8. What do you understand about skewness in data?
#
# Ans.
#
# Skewness is the degree of asymmetry observed in a probability distribution. When data points on a bell curve are not distributed symmetrically to the left and right sides of the median, the bell curve is skewed. Distributions can be positive and right-skewed, or negative and left-skewed.

# %% [markdown]
# Q9. If a data is right skewed then what will be the position of median with respect to mean?
#
# Ans.
#
# If the distribution of data is skewed to the right, the mode is often less than the median, which is less than the mean.

# %% [markdown]
# Q10. Explain the difference between covariance and correlation. How are these measures used in
# statistical analysis?
#
# Ans.
#
# Covariance reveals how two variables change together while correlation determines how closely two variables are related to each other. Both covariance and correlation measure the relationship and the dependency between two variables. Covariance indicates the direction of the linear relationship between variables.

# %% [markdown]
# Q11. What is the formula for calculating the sample mean? Provide an example calculation for a
# dataset.
#
# Ans.
#
# The sample mean, often denoted as
# 𝑥
# ˉ
# x
# ˉ
#  , is the average value of a dataset. It is calculated by summing all the data points in the sample and dividing by the number of data points
# 𝑛
# n.
#
# Formula for Sample Mean
# 𝑥
# ˉ
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑥
# 𝑖
# 𝑛
# x
# ˉ
#  =
# n
# ∑
# i=1
# n
# ​
#  x
# i
# ​
#
# ​
#
#
# where:
#
# 𝑥
# ˉ
# x
# ˉ
#   is the sample mean,
# 𝑥
# 𝑖
# x
# i
# ​
#   are the individual data points,
# 𝑛
# n is the number of data points in the sample.
# Example Calculation
# Let's calculate the sample mean for a dataset:
#
# Dataset:
# [
# 10
# ,
# 15
# ,
# 12
# ,
# 18
# ,
# 20
# ]
# Dataset: [10,15,12,18,20]
#
# Sum all the data points:
# ∑
# 𝑖
# =
# 1
# 5
# 𝑥
# 𝑖
# =
# 10
# +
# 15
# +
# 12
# +
# 18
# +
# 20
# =
# 75
# ∑
# i=1
# 5
# ​
#  x
# i
# ​
#  =10+15+12+18+20=75
#
# Count the number of data points:
# 𝑛
# =
# 5
# n=5
#
# Calculate the sample mean
# 𝑥
# ˉ
# x
# ˉ
#  :
# 𝑥
# ˉ
# =
# 75
# 5
# =
# 15
# x
# ˉ
#  =
# 5
# 75
# ​
#  =15

# %% [markdown]
# Q12. For a normal distribution data what is the relationship between its measure of central tendency?
#
# Ans.
#
# For a normal distribution, the measures of central tendency—mean, median, and mode—are all equal. This property is a key characteristic of a normal distribution and helps in understanding its symmetrical nature.

# %% [markdown]
# Q13. How is covariance different from correlation?
#
# Ans.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.
#
# Ans.
#
# Outliers can significantly impact measures of central tendency and dispersion in a dataset. Here’s how:
#
# Measures of Central Tendency
# Mean:
#
# The mean is highly sensitive to outliers because it is calculated by summing all values and dividing by the number of values. An extreme value can significantly increase or decrease the mean.
# Example: Consider the dataset
# [
# 10
# ,
# 12
# ,
# 14
# ,
# 16
# ,
# 100
# ]
# [10,12,14,16,100]. The mean is
# 10
# +
# 12
# +
# 14
# +
# 16
# +
# 100
# 5
# =
# 30.4
# 5
# 10+12+14+16+100
# ​
#  =30.4. The outlier (100) has drastically increased the mean from what would have been 13 if the outlier were not present.
# Median:
#
# The median is less sensitive to outliers because it is the middle value of a sorted dataset. Outliers do not affect the median as much because they do not change the position of the middle value.
# Example: For the dataset
# [
# 10
# ,
# 12
# ,
# 14
# ,
# 16
# ,
# 100
# ]
# [10,12,14,16,100], the median is 14. If the outlier (100) were not present, the median would still be 14 in this example, illustrating its robustness.
# Mode:
#
# The mode is typically unaffected by outliers, as it represents the most frequent value in a dataset.
# Example: In the dataset
# [
# 10
# ,
# 10
# ,
# 14
# ,
# 16
# ,
# 100
# ]
# [10,10,14,16,100], the mode is 10, and it remains unaffected by the outlier 100.
